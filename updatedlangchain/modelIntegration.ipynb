# %% [markdown]
# ### Models integration with google gemini and groq

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %% [markdown]
# ### Google gemini - Free model can't be used due to qouta reached

# %% [markdown]
# import os
# from langchain.chat_models import init_chat_model
#
# os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
#
# model = init_chat_model("google_genai:gemini-2.0-flash")
# response = model.invoke("what is the capital of france?")
# response.content

# %% [markdown]
# ### Groq model

# %%
import os 
from langchain.chat_models import init_chat_model 

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:llama-3.3-70b-versatile")
response = model.invoke("why do parrots talk?")
response.content
# Out:
# "Parrots are known for their remarkable ability to mimic human speech and other sounds, but why do they do it? The answer lies in their evolution, social behavior, and communication needs.\n\n**In the wild:**\n\nIn their natural habitats, parrots use vocalizations to communicate with each other for various purposes, such as:\n\n1. **Contact calls**: To maintain contact with their flock members, especially when foraging or flying.\n2. **Alarm calls**: To warn other parrots of potential predators or threats.\n3. **Courtship and mating**: To attract a mate or strengthen pair bonds.\n4. **Territorial defense**: To defend their territory from other parrots or competitors.\n\nParrots have a highly developed syrinx, a vocal organ located at the base of the trachea, which enables them to produce a wide range of sounds, including complex vocalizations.\n\n**Mimicry:**\n\nParrots are renowned for their ability to mimic other sounds, including human speech. This mimicry serves several purposes:\n\n1. **Social bonding**: By mimicking their human caregivers or other parrots, parrots can strengthen social bonds and create a sense of belonging.\n2. **Attention-seeking**: Parrots may mimic human speech to get attention from their owners or to initiate interaction.\n3. **Learning and problem-solving**: Mimicry helps parrots learn about their environment and solve problems, such as figuring out how to open a door or find food.\n4. **Play and entertainment**: Parrots may mimic sounds simply because it's fun and entertaining for them!\n\n**Brain structure:**\n\nParrots have a large brain-to-body mass ratio, which suggests a high level of intelligence and cognitive ability. Their brain structure, particularly the areas responsible for vocal learning and production, is similar to that of humans and other primates.\n\n**Domestication and training:**\n\nWhen parrots are domesticated and trained, they can learn to mimic human speech and other sounds more effectively. This is often encouraged by owners who want to interact with their parrots and teach them tricks.\n\nIn summary, parrots talk because it's an essential part of their communication and social behavior in the wild, and they have the cognitive ability and physical attributes to mimic a wide range of sounds, including human speech."
